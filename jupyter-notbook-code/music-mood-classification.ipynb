# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load
import joblib
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns # Seaborn for data visualization
from tensorflow.keras.models import load_model
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# Load the data
df = pd.read_csv('data_moods.csv')
df
# Out:
#                                             name  \
# 0                                           1999
# 1                                             23
# 2                                       9 Crimes
# 3                                 99 Luftballons
# 4    A Boy Brushed Red Living In Black And White
# ..                                           ...
# 681                                  windcatcher
# 682              yellow is the color of her eyes
# 683                           you broke me first
# 684                          you were good to me
# 685                                         æfre
#
#                                album          artist                      id  \
# 0                               1999          Prince  2H7PHVdQ3mXqEHXcvclTB0
# 1                                 23  Blonde Redhead  4HIwL9ii9CcXpTOTzMq0MP
# 2                                  9     Damien Rice  5GZEeowhvSieFDiR8fQ2im
# ...

# %%
# Checking null value in dataset
df.isnull().sum()
# Out:
# name                0
# album               0
# artist              0
# id                  0
# release_date        0
# popularity          0
# length              0
# danceability        0
# acousticness        0
# energy              0
# instrumentalness    0
# liveness            0
# valence             0
# loudness            0
# speechiness         0
# tempo               0
# key                 0
# time_signature      0
# mood                0
# dtype: int64

# %%
# Visualize number of data point for each class
#sns.countplot(df['mood'])

# %% [markdown]
# # Data Preparation

# %%
# Feature engineering
X = df.loc[:, 'popularity':'time_signature']
X['length'] = X['length']/max(X['length'])

# Mapping class label to respected integer
y = df['mood'].map({'Happy': 0, 'Sad': 1, 'Energetic': 2, 'Calm':3})
target_names = ['Happy', 'Sad', 'Energetic', 'Calm']

# %%
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier
from lightgbm import LGBMClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

# %%
# Splitting training data and testing data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
X_test
# Out:
#      popularity    length  danceability  acousticness  energy  \
# 482           0  0.321313         0.684      0.905000  0.0646
# 23           39  0.423581         0.429      0.000019  0.9820
# 189          47  0.462987         0.500      0.671000  0.1850
# 47            0  0.560863         0.399      0.848000  0.4430
# 363          74  0.569860         0.586      0.058900  0.7000
# ..          ...       ...           ...           ...     ...
# 365          25  0.482998         0.665      0.336000  0.5600
# 362          72  0.326070         0.494      0.001290  0.9460
# 378          66  0.459077         0.581      0.893000  0.4000
# 262          57  0.393435         0.432      0.807000  0.3400
# 666          49  0.462023         0.634      0.819000  0.1930
#
#      instrumentalness  liveness  valence  loudness  speechiness    tempo  key  \
# 482          0.000019    0.0789    0.334   -18.052       0.0522   95.990   10
# ...

# %%
models = []
models.append(('Random Forest Classifier',RandomForestClassifier()))
models.append(('Gradient Boosting Classifier',GradientBoostingClassifier()))
models.append(('XGB Classifier', XGBClassifier()))
models.append(('Decision Tree Classifier', DecisionTreeClassifier()))
models.append(('LGBM Classifier', LGBMClassifier()))
models.append(('Support Vector Classifier', SVC()))
models.append(('KNN Classifier', KNeighborsClassifier()))
save_dir='trained_model_classifiers'
for name, model in models:
    model.fit(X_train, y_train)

    predictions = model.predict(X_test)
    accuracy = accuracy_score(predictions, y_test)

    print('Accuracy for {} : {:3.3f}\nClassification Report for {} : \n{}'.format(name, accuracy_score(predictions, y_test), name, classification_report(predictions, y_test, target_names=target_names)))
    model_filename = os.path.join(save_dir, f'{name}.joblib')
    joblib.dump(model, model_filename)
# Out:
# Accuracy for Random Forest Classifier : 0.848
# Classification Report for Random Forest Classifier :
#               precision    recall  f1-score   support
#
#        Happy       0.65      0.60      0.63        25
#          Sad       0.90      0.93      0.92        41
#    Energetic       0.78      0.81      0.79        36
#         Calm       0.97      0.97      0.97        36
#
#     accuracy                           0.85       138
#    macro avg       0.83      0.83      0.83       138
# weighted avg       0.85      0.85      0.85       138
#
# Accuracy for Gradient Boosting Classifier : 0.855
# Classification Report for Gradient Boosting Classifier :
#               precision    recall  f1-score   support
#
#        Happy       0.70      0.62      0.65        26
#          Sad       0.95      0.93      0.94        43
#    Energetic       0.70      0.81      0.75        32
#         Calm       1.00      0.97      0.99        37
#
# ...

# %%
#model.save('mood_predict.h5')

# %%
#mood_model = load_model('mood_predict.h5')
# Load the saved models
loaded_models = []
loaded_models.append(('Random Forest Classifier', joblib.load('trained_model_classifiers/Random Forest Classifier.joblib')))
loaded_models.append(('Gradient Boosting Classifier', joblib.load('trained_model_classifiers/Gradient Boosting Classifier.joblib')))
loaded_models.append(('XGB Classifier', joblib.load('trained_model_classifiers/XGB Classifier.joblib')))
loaded_models.append(('Decision Tree Classifier', joblib.load('trained_model_classifiers/Decision Tree Classifier.joblib')))
loaded_models.append(('LGBM Classifier', joblib.load('trained_model_classifiers/LGBM Classifier.joblib')))
loaded_models.append(('Support Vector Classifier', joblib.load('trained_model_classifiers/Support Vector Classifier.joblib')))
loaded_models.append(('KNN Classifier', joblib.load('trained_model_classifiers/KNN Classifier.joblib')))

# %%
import spotipy
import os
from spotipy.oauth2 import SpotifyClientCredentials
from collections import defaultdict

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id="357958d690d54634b3f3dd218988bf83",
                                                           client_secret="57947d24dfdd418698691ec29c52c247"))

def find_song(name):
    song_data = defaultdict()
    results = sp.search(q= 'track: {}'.format(name), limit=1)
    if results['tracks']['items'] == []:
        return None

    results = results['tracks']['items'][0]
    track_id = results['id']
    audio_features = sp.audio_features(track_id)[0]

    song_data['name'] = [name]
    song_data['popularity'] = [results['popularity']]
    song_data['length'] = [results['duration_ms']]
    song_data['danceability'] = [audio_features['danceability']]
    song_data['acousticness'] = [audio_features['acousticness']]
    song_data['energy'] = [audio_features['energy']]
    song_data['instrumentalness'] = [audio_features['instrumentalness']]
    song_data['liveness'] = [audio_features['liveness']]
    song_data['valence'] = [audio_features['valence']]
    song_data['loudness'] = [audio_features['loudness']]
    song_data['speechiness'] = [audio_features['speechiness']]
    song_data['tempo'] = [audio_features['tempo']]
    song_data['key'] = [audio_features['key']]    
    song_data['time_signature'] = [audio_features['time_signature']]
    
    #print(audio_features)
    
    #for key, value in audio_features.items():
     #    song_data[key] = value

    return pd.DataFrame(song_data)

#songdetails=find_song('Come As You Are')
#songdetails
#print(songdetails)

# %%
# Preprocess the new song's data
# new_song_data = {
#     "name":"A Boy Brushed Red Living In Black And White",
#     "popularity": 60,
#     "length": 268000,
#     "danceability": 0.419,
#     "acousticness": 0.00171,
#     "energy": 0.932,
#     "instrumentalness": 0.0,
#     "liveness": 0.137,
#     "valence": 0.445,
#     "loudness": -3.604,
#     "speechiness": 0.106,
#     "tempo": 169.881,
#     "key": 1,
#     "time_signature": 4,
# }

# Convert new song's data into a DataFrame
#new_song_df = pd.DataFrame([new_song_data])
new_song_df=find_song('Tum hi ho')

# Scale the new song's data
new_song_scaled = new_song_df.copy()
new_song_scaled['length'] = new_song_scaled['length'] / max(X['length'])  # Scale the length feature
new_song_scaled = new_song_scaled.drop(columns=['name'])
mood_count = {}  # Dictionary to count predicted moods

# Predict mood using trained models
for name, model in loaded_models:
    mood_prediction = model.predict(new_song_scaled)
    predicted_mood = target_names[mood_prediction[0]]  # Get the predicted mood label
    if predicted_mood in mood_count:
        mood_count[predicted_mood] += 1
    else:
        mood_count[predicted_mood] = 1

    # Find the most common predicted mood
    most_common_mood = max(mood_count, key=mood_count.get)

    #print('\033[1mPredicted Mood for ' + new_song_data['name'] + '\033[0m' + ' using ' + name + ': \033[1m' + predicted_mood + '\033[0m')
print(mood_count)
print('\033[1mPredicted Mood for ' + new_song_df['name'] + '\033[0m' + ': \033[1m' + most_common_mood + '\033[0m')
# Out:
# {'Sad': 4, 'Happy': 3}
# 0    Predicted Mood for Tum hi ho: Sad
# Name: name, dtype: object

# %%
# Predict mood using trained models
similar_songs = []  # List to store similar song information
for name, model in loaded_models:
    mood_prediction = model.predict(new_song_scaled)
    predicted_mood = target_names[mood_prediction[0]]  # Get the predicted mood label
    
    # Filter the original dataset to find songs with the predicted mood
    similar_songs_by_mood = df[df['mood'] == predicted_mood]
    similar_songs.append(similar_songs_by_mood)

# Concatenate the list of similar song DataFrames into a single DataFrame
similar_songs_df = pd.concat(similar_songs, ignore_index=True)

print("Similar Songs with Predicted Mood:")
print(similar_songs_df[['name', 'mood']])
# Out:
# Similar Songs with Predicted Mood:
#                                          name   mood
# 0                                          23    Sad
# 1                                    9 Crimes    Sad
# 2                                 Algo Rhythm    Sad
# 3                                      Alison    Sad
# 4                                  All I Want    Sad
# ...                                       ...    ...
# 1203                               Wonderwall  Happy
# 1204       Worlds Collide - Edison Cole Remix  Happy
# 1205                You Can't Rely on My Love  Happy
# 1206                    You Get What You Give  Happy
# 1207  You're My Best Friend - Remastered 2011  Happy
#
# [1208 rows x 2 columns]
